# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhakthipoorna/machine-learning/blob/main/SQL_for_DataScience_Fullversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (1.3.22)
# Requirement already satisfied: pymysql in /usr/local/lib/python3.6/dist-packages (1.0.2)

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_host = '54.255.64.49:3306' # port: 3306
username = 'dm_user_sql'
user_pass = '37z49REb$nK@nlpV!vJ'
db_name = 'datamites_sql'

conn = create_engine('mysql+pymysql://'+username+':'+user_pass+'@'+db_host+'/'+db_name)
conn.table_names()
# Out:
# ['customers', 'orders', 'products']

# %%
query = "select * from orders" # SQL statement
orders = pd.read_sql(query,conn)
print(orders.shape)
orders
# Out:
# (9, 6)
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %%
query = "select * from customers"
customers = pd.read_sql(query,conn)
print(customers.shape)
customers
# Out:
# (10, 5)
#   customer_id       customer_name             city           state  postal_code
# 0    AA-10480        Andrew Allen          Concord  North Carolina        28027
# 1    AG-10270     Alejandro Grove      West Jordan            Utah        84084
# 2    BH-11710     Brosina Hoffman      Los Angeles      California        90032
# 3    CG-12520         Claire Gute        Henderson        Kentucky        42420
# 4    DV-13045     Darrin Van Huff      Los Angeles      California        90036
# 5    HP-14815       Harold Pawlan       Fort Worth           Texas        76106
# 6    IM-15070        Irene Maddox          Seattle      Washington        98103
# 7    PK-19075           Pete Kriz          Madison       Wisconsin        53711
# 8    SO-20335      Sean O'Donnell  Fort Lauderdale         Florida        33311
# 9    ZD-21925  Zuschuss Donatelli    San Francisco      California        94109

# %%
query = "select * from products"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (14, 4)
#          product_id  ...                                       product_name
# 0   FUR-BO-10001798  ...                  Bush Somerset Collection Bookcase
# 1   FUR-CH-10000454  ...  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   FUR-FU-10001487  ...  Eldon Expressions Wood and Plastic Desk Access...
# 3   FUR-TA-10000577  ...      Bretford CR4500 Series Slim Rectangular Table
# 4   FUR-TA-10001539  ...           Chromcraft Rectangular Conference Tables
# 5   OFF-AP-10002892  ...                   Belkin F5C206VTEL 6 Outlet Surge
# 6   OFF-AR-10002833  ...                                         Newell 322
# 7   OFF-BI-10003656  ...        Fellowes PB200 Plastic Comb Binding Machine
# 8   OFF-BI-10003910  ...  DXL Angle-View Binders with Locking Rings by S...
# 9   OFF-LA-10000240  ...  Self-Adhesive Address Labels for Typewriters b...
# 10  OFF-PA-10002365  ...                                         Xerox 1967
# 11  OFF-ST-10000760  ...                     Eldon Fold 'N Roll Cart System
# 12  TEC-PH-10002033  ...    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 13  TEC-PH-10002275  ...                     Mitel 5320 IP Phone VoIP phone
#
# [14 rows x 4 columns]

# %% [markdown]
# # SQL Where Condition

# %%
query = "select * from products where category='Furniture'"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (5, 4)
#         product_id  ...                                       product_name
# 0  FUR-BO-10001798  ...                  Bush Somerset Collection Bookcase
# 1  FUR-CH-10000454  ...  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  FUR-FU-10001487  ...  Eldon Expressions Wood and Plastic Desk Access...
# 3  FUR-TA-10000577  ...      Bretford CR4500 Series Slim Rectangular Table
# 4  FUR-TA-10001539  ...           Chromcraft Rectangular Conference Tables
#
# [5 rows x 4 columns]

# %% [markdown]
# # SQL Where Condition and logical statement

# %%
query = "select * from products where category='Furniture' or category='Technology'"
products = pd.read_sql(query,conn)
print(products.shape)
products
# Out:
# (7, 4)
#         product_id  ...                                       product_name
# 0  FUR-BO-10001798  ...                  Bush Somerset Collection Bookcase
# 1  FUR-CH-10000454  ...  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  FUR-FU-10001487  ...  Eldon Expressions Wood and Plastic Desk Access...
# 3  FUR-TA-10000577  ...      Bretford CR4500 Series Slim Rectangular Table
# 4  FUR-TA-10001539  ...           Chromcraft Rectangular Conference Tables
# 5  TEC-PH-10002033  ...    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 6  TEC-PH-10002275  ...                     Mitel 5320 IP Phone VoIP phone
#
# [7 rows x 4 columns]

# %% [markdown]
# ## SQL Left Join
# also called as Left Outer Join

# %%
# fechting only customers details who have orders
query = "select * from orders  left join customers on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (9, 11)
#          order_id  order_date  ...           state postal_code
# 0  CA-2015-115812    6/9/2015  ...      California       90032
# 1  CA-2017-105654  12/10/2017  ...      California       90032
# 2  CA-2017-138688   6/12/2017  ...      California       90036
# 3  CA-2017-152156   11/8/2017  ...        Kentucky       42420
# 4  CA-2018-109265    2/8/2018  ...      California       90032
# 5  CA-2018-109862    4/9/2018  ...      California       90036
# 6  CA-2018-112417    6/8/2018  ...         Florida       33311
# 7  CA-2018-114412   4/11/2018  ...  North Carolina       28027
# 8  US-2016-108966  10/11/2017  ...         Florida       33311
#
# [9 rows x 11 columns]

# %% [markdown]
# ## SQL Right Join
# Also called as Right outer join

# %%
# fechting only customers details who have orders
query = "select * from orders  right join customers on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (14, 11)
#           order_id  order_date  ...           state postal_code
# 0   CA-2015-115812    6/9/2015  ...      California       90032
# 1   CA-2017-105654  12/10/2017  ...      California       90032
# 2   CA-2017-138688   6/12/2017  ...      California       90036
# 3   CA-2017-152156   11/8/2017  ...        Kentucky       42420
# 4   CA-2018-109265    2/8/2018  ...      California       90032
# 5   CA-2018-109862    4/9/2018  ...      California       90036
# 6   CA-2018-112417    6/8/2018  ...         Florida       33311
# 7   CA-2018-114412   4/11/2018  ...  North Carolina       28027
# 8   US-2016-108966  10/11/2017  ...         Florida       33311
# 9             None        None  ...            Utah       84084
# 10            None        None  ...           Texas       76106
# 11            None        None  ...      Washington       98103
# 12            None        None  ...       Wisconsin       53711
# 13            None        None  ...      California       94109
#
# [14 rows x 11 columns]

# %%
# fechting only customers details who have orders
query = "select * from customers  right join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data.head(50)
# Out:
# (9, 11)
#   customer_id    customer_name  ...   sales quantity
# 0    BH-11710  Brosina Hoffman  ...  48.860        7
# 1    BH-11710  Brosina Hoffman  ...  71.530        3
# 2    DV-13045  Darrin Van Huff  ...  14.620        2
# 3    CG-12520      Claire Gute  ...  58.960        2
# 4    BH-11710  Brosina Hoffman  ...  14.620        5
# 5    DV-13045  Darrin Van Huff  ...  15.552        1
# 6    SO-20335   Sean O'Donnell  ...  15.552        2
# 7    AA-10480     Andrew Allen  ...  15.552        3
# 8    SO-20335   Sean O'Donnell  ...  69.650        5
#
# [9 rows x 11 columns]

# %% [markdown]
# ## SQL Inner Join
# This is default

# %%
# fechting only customers details who have orders
query = "select * from customers  inner join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,conn)
print(data.shape)
data.head(50)
# Out:
# (9, 11)
#   customer_id    customer_name  ...   sales quantity
# 0    BH-11710  Brosina Hoffman  ...  48.860        7
# 1    BH-11710  Brosina Hoffman  ...  71.530        3
# 2    DV-13045  Darrin Van Huff  ...  14.620        2
# 3    CG-12520      Claire Gute  ...  58.960        2
# 4    BH-11710  Brosina Hoffman  ...  14.620        5
# 5    DV-13045  Darrin Van Huff  ...  15.552        1
# 6    SO-20335   Sean O'Donnell  ...  15.552        2
# 7    AA-10480     Andrew Allen  ...  15.552        3
# 8    SO-20335   Sean O'Donnell  ...  69.650        5
#
# [9 rows x 11 columns]

# %% [markdown]
# #  Join multiple tables

# %%
# fechting only customers details who have orders
query = "select * from orders  \
left join customers on orders.customer_id=customers.customer_id \
left join products  on orders.product_id = products.product_id"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (9, 15)
#          order_id  ...                                       product_name
# 0  CA-2015-115812  ...  Eldon Expressions Wood and Plastic Desk Access...
# 1  CA-2017-105654  ...      Bretford CR4500 Series Slim Rectangular Table
# 2  CA-2017-138688  ...  Self-Adhesive Address Labels for Typewriters b...
# 3  CA-2017-152156  ...                  Bush Somerset Collection Bookcase
# 4  CA-2018-109265  ...  Self-Adhesive Address Labels for Typewriters b...
# 5  CA-2018-109862  ...                                         Xerox 1967
# 6  CA-2018-112417  ...                                         Xerox 1967
# 7  CA-2018-114412  ...                                         Xerox 1967
# 8  US-2016-108966  ...      Bretford CR4500 Series Slim Rectangular Table
#
# [9 rows x 15 columns]

# %% [markdown]
# ## Quick Assessment

# %% [markdown]
# Fetch Orders information of the customers from the California State?

# %% [markdown]
# Fetch Orders information of customers from california who ordered furnitures

# %%
query = "select * from orders  left join customers on orders.customer_id=customers.customer_id where state='California'"
data = pd.read_sql(query,conn)
print(data.shape)
data
# Out:
# (5, 11)
#          order_id  order_date customer_id  ...         city       state  postal_code
# 0  CA-2015-115812    6/9/2015    BH-11710  ...  Los Angeles  California        90032
# 1  CA-2017-105654  12/10/2017    BH-11710  ...  Los Angeles  California        90032
# 2  CA-2017-138688   6/12/2017    DV-13045  ...  Los Angeles  California        90036
# 3  CA-2018-109265    2/8/2018    BH-11710  ...  Los Angeles  California        90032
# 4  CA-2018-109862    4/9/2018    DV-13045  ...  Los Angeles  California        90036
#
# [5 rows x 11 columns]
